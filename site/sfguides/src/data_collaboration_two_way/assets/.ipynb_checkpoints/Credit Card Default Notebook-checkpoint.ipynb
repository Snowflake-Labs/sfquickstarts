# %% [markdown]
# # Environment Setup

# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.version import VERSION
import snowflake.snowpark as snp
import snowflake.snowpark.functions as F
import snowflake.snowpark.types as T
import snowflake.snowpark.window as W

import pandas as pd
import json
import seaborn as sns

from snowflake.ml.modeling.lightgbm import LGBMClassifier
from snowflake.ml.modeling.metrics import *

# %% [markdown]
# ## Create Snowpark Session

# %%
# Make a Snowpark Connection
# Edit the connection.json before creating the session object below
# Create Snowflake Session object

connection_parameters = json.load(open('connection.json'))
session = Session.builder.configs(connection_parameters).create()
# require specific numpy version for LGBM
session.custom_package_usage_config = {"enabled": True}
session.add_packages(["numpy==1.26.3"])

snowflake_environment = session.sql('SELECT current_user(), current_version()').collect()
snowpark_version = VERSION

# Current Environment Details
print('\nConnection Established with the following parameters:')
print('User                        : {}'.format(snowflake_environment[0][0]))
print('Role                        : {}'.format(session.get_current_role()))
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
print('Warehouse                   : {}'.format(session.get_current_warehouse()))
print('Snowflake version           : {}'.format(snowflake_environment[0][1]))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# Parameter custom_package_usage_config is experimental since 1.6.0. Do not use it in production.
# The following packages are not available in Snowflake: ['numpy==1.26.3'].
# If you are adding package(s) unavailable in Snowflake, it is highly recommended that you include the 'cache_path' configuration parameter in order to reduce latency.
# Package numpy(version 1.26.3) contains native code, switching to latest available version in Snowflake instead.
# Connection Established with the following parameters:
# User                        : JOHN
# Role                        : "ACCOUNTADMIN"
# Database                    : "SCORED_MODEL"
# Schema                      : "SCORED_MODEL"
# Warehouse                   : "QUERY_WH"
# Snowflake version           : 8.1.0
# Snowpark for Python version : 1.11.1

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# This notebook is based on the worksheet found here (https://www.kaggle.com/code/ambrosm/amex-lightgbm-quickstart), with some modifications. The dataset has multiple values per customer ID, so we will undertake some feature engineering to find the mean, standard deviation, min, max and last values of each customer ID, so we have features and customer ID as a unique key.

# %%
#Create Snowpark df from shared data
training_df = session.table('"CC_DEFAULT_TRAINING_DATA"."DATA_SHARING_DEMO"."CC_DEFAULT_TRAINING_DATA"')

# %%
# Check number of rows (5,531,451 rows)
training_df.count()
# Out:
# 5531451

# %%
# Check first 5 rows
training_df.show(5)
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"D_60"              |"D_61"  |"B_15"              |"S_11"              |"D_62"  |"D_63"  |"D_64"  |"D_65"                 |"B_16"                  |"B_17"  |"B_18"              |"B_19"                 |"D_66"  |"B_20"                  |"D_68"  |"S_12"               |"R_6"                  |"S_13"              |"B_21"                 |"D_69"                 |"B_22"                |"D_70"                 |"D_71"               |"D_72"                  |"R_12"              |"B_28"               |"R_13"  |"D_83"                 |"R_14"                 |"R_15"  |"D_84"                  |"R_16"                  |"B_29"  |"B_30"  |"S_18"  |"D_86"  |"D_87"  |"R_17"  |"R_18"  |"D_88"  |"B_31"  |"S_19"  |"R_19"  |"B_32"  |"S_20"  |"R_20"                 |"R_21"  |"B_33"  |"S_15"               |"B_23"                |"D_73"  |
0       |NULL     |-127     |NULL     |-127     |NULL     |0        |0        |0.0021390921901911497  |NULL     |0        |0.005851833149790764  |0.007493703160434961   |0         |735026906d69a9862599d86934cd197c1cc0ff8aa85bfef...  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# For the next section, we are going to perform feature engineering create three groups of features:
# - Selected features averaged over all statements of a customer
# - The minimum or maximum of selected features over all statements of a customer
# - Selected features taken from the last statement of a customer

# %%
# The following cells create the average numerical values for selected features per customer
features_avg = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_8', 'B_9', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_20', 'B_21', 'B_22', 'B_23', 'B_24', 'B_25', 'B_28', 'B_29', 'B_30', 'B_32', 'B_33', 'B_37', 'B_38', 'B_39', 'B_40', 'B_41', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_50', 'D_51', 'D_53', 'D_54', 'D_55', 'D_58', 'D_59', 'D_60', 'D_61', 'D_62', 'D_65', 'D_66', 'D_69', 'D_70', 'D_71', 'D_72', 'D_73', 'D_74', 'D_75', 'D_76', 'D_77', 'D_78', 'D_80', 'D_82', 'D_84', 'D_86', 'D_91', 'D_92', 'D_94', 'D_96', 'D_103', 'D_104', 'D_108', 'D_112', 'D_113', 'D_114', 'D_115', 'D_117', 'D_118', 'D_119', 'D_120', 'D_121', 'D_122', 'D_123', 'D_124', 'D_125', 'D_126', 'D_128', 'D_129', 'D_131', 'D_132', 'D_133', 'D_134', 'D_135', 'D_136', 'D_140', 'D_141', 'D_142', 'D_144', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_2', 'R_3', 'R_7', 'R_8', 'R_9', 'R_10', 'R_11', 'R_14', 'R_15', 'R_16', 'R_17', 'R_20', 'R_21', 'R_22', 'R_24', 'R_26', 'R_27', 'S_3', 'S_5', 'S_6', 'S_7', 'S_9', 'S_11', 'S_12', 'S_13', 'S_15', 'S_16', 'S_18', 'S_22', 'S_23', 'S_25', 'S_26']

# %%
feat = [F.col(c) for c in features_avg]

# %%
exprs = {x: "avg" for x in features_avg}

# %%
df_avg = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs)
          .rename({F.col(f"AVG({f})"): f"{f}_avg" for f in features_avg})
         )

# %%
df_avg.count()
# Out:
# 458913

# %%
# The following cells create the minimum numerical values for selected features per customer
features_min = ['B_2', 'B_4', 'B_5', 'B_9', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_19', 'B_20', 'B_28', 'B_29', 'B_33', 'B_36', 'B_42', 'D_39', 'D_41', 'D_42', 'D_45', 'D_46', 'D_48', 'D_50', 'D_51', 'D_53', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_62', 'D_70', 'D_71', 'D_74', 'D_75', 'D_78', 'D_83', 'D_102', 'D_112', 'D_113', 'D_115', 'D_118', 'D_119', 'D_121', 'D_122', 'D_128', 'D_132', 'D_140', 'D_141', 'D_144', 'D_145', 'P_2', 'P_3', 'R_1', 'R_27', 'S_3', 'S_5', 'S_7', 'S_9', 'S_11', 'S_12', 'S_23', 'S_25']

# %%
exprs_min = {x: "min" for x in features_min}

# %%
df_min = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs_min)
          .rename({F.col(f"MIN({f})"): f"{f}_min" for f in features_min})
         )

# %%
df_min.count()
# Out:
# 458913

# %%
# The following cells create the maximum numerical values for selected features per customer
features_max = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_7', 'B_8', 'B_9', 'B_10', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_21', 'B_23', 'B_24', 'B_25', 'B_29', 'B_30', 'B_33', 'B_37', 'B_38', 'B_39', 'B_40', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_52', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_61', 'D_63', 'D_64', 'D_65', 'D_70', 'D_71', 'D_72', 'D_73', 'D_74', 'D_76', 'D_77', 'D_78', 'D_80', 'D_82', 'D_84', 'D_91', 'D_102', 'D_105', 'D_107', 'D_110', 'D_111', 'D_112', 'D_115', 'D_116', 'D_117', 'D_118', 'D_119', 'D_121', 'D_122', 'D_123', 'D_124', 'D_125', 'D_126', 'D_128', 'D_131', 'D_132', 'D_133', 'D_134', 'D_135', 'D_136', 'D_138', 'D_140', 'D_141', 'D_142', 'D_144', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_3', 'R_5', 'R_6', 'R_7', 'R_8', 'R_10', 'R_11', 'R_14', 'R_17', 'R_20', 'R_26', 'R_27', 'S_3', 'S_5', 'S_7', 'S_8', 'S_11', 'S_12', 'S_13', 'S_15', 'S_16', 'S_22', 'S_23', 'S_24', 'S_25', 'S_26', 'S_27']

# %%
exprs_max = {x: "max" for x in features_max}

# %%
df_max = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs_max)
          .rename({F.col(f"MAX({f})"): f"{f}_max" for f in features_max})
         )

# %%
df_max.count()
# Out:
# 458913

# %%
# The following cells create the last numerical values for selected features per customer, with S_2 being the date field.
features_last = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_7', 'B_8', 'B_9', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_20', 'B_21', 'B_22', 'B_23', 'B_24', 'B_25', 'B_26', 'B_28', 'B_29', 'B_30', 'B_32', 'B_33', 'B_36', 'B_37', 'B_38', 'B_39', 'B_40', 'B_41', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_51', 'D_52', 'D_53', 'D_54', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_61', 'D_62', 'D_63', 'D_64', 'D_65', 'D_69', 'D_70', 'D_71', 'D_72', 'D_73', 'D_75', 'D_76', 'D_77', 'D_78', 'D_79', 'D_80', 'D_81', 'D_82', 'D_83', 'D_86', 'D_91', 'D_96', 'D_105', 'D_106', 'D_112', 'D_114', 'D_119', 'D_120', 'D_121', 'D_122', 'D_124', 'D_125', 'D_126', 'D_127', 'D_130', 'D_131', 'D_132', 'D_133', 'D_134', 'D_138', 'D_140', 'D_141', 'D_142', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_2', 'R_3', 'R_4', 'R_5', 'R_6', 'R_7', 'R_8', 'R_9', 'R_10', 'R_11', 'R_12', 'R_13', 'R_14', 'R_15', 'R_19', 'R_20', 'R_26', 'R_27', 'S_3', 'S_5', 'S_6', 'S_7', 'S_8', 'S_9', 'S_11', 'S_12', 'S_13', 'S_16', 'S_19', 'S_20', 'S_22', 'S_23', 'S_24', 'S_25', 'S_26', 'S_27', '"customer_ID"', '"target"']

# %%
w = snp.Window.partition_by('"customer_ID"').order_by(F.col('S_2').desc())

# %%
df_last = training_df.withColumn("rn", F.row_number().over(w)).filter("rn = 1").select(features_last)

# %%
df_last.count()
# Out:
# 458913

# %%
# Now we join these dataframes on customer ID
feature_df = df_min.natural_join(df_avg)

# %%
feature_df = feature_df.natural_join(df_max)

# %%
feature_df = feature_df.natural_join(df_last)

# %%
feature_df.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |"customer_ID"                                       |"B_2_MIN"              |"B_4_MIN"              |"B_5_MIN"               |"B_9_MIN"               |"B_13_MIN"             |"B_14_MIN"              |"B_15_MIN"              |"B_16_MIN"             |"B_17_MIN"             |"B_19_MIN"              |"B_20_MIN"              |"B_28_MIN"            |"B_29_MIN"             |"B_33_MIN"  |"B_36_MIN"  |"B_42_MIN"  |"D_39_MIN"             |"D_41_MIN"              |"D_42_MIN"           |"D_45_MIN"             |"D_46_MIN"           |"D_48_MIN"            |"D_50_MIN"           |"D_51_MIN"              |"D_53_MIN"             |"D_55_MIN"             |"D_56_MIN"            |"D_58_MIN"             |"D_59_MIN"           |"D_60_MIN"              |"D_62_MIN"            |"D_70_MIN"              |"D_71_MIN"             |"D_74_MIN"              |"D_75_MIN"             |"D_78_MIN"             |"D_83_MIN"              |"D_102_MIN"             |"D_112_MIN"  |"D_113_MIN"             |"D_115_MIN"           |"D_118_MIN"            |"D_119_MIN"            |"D_121_MIN"          |"D_122_MIN"          |"D_128_MIN"  |"D_132_MIN"          |"D_140_MIN"  |"D_141_MIN"             |"D_144_MIN"             |"D_145_MIN"            |"P_2_MIN"             |"P_3_MIN"            |"R_1_MIN"               |"R_27_MIN"  |"S_3_MIN"            |"S_5_MIN"               |"S_7_MIN"            |"S_9_MIN"              |"S_11_MIN"            |"S_12_MIN"            |"S_23_MIN"           |"S_25_MIN"          |"B_1_AVG"             |"B_2_AVG"             |"B_3_AVG"              |"B_4_AVG"             |"B_5_AVG"             |"B_6_AVG"             |"B_8_AVG"   |"B_9_AVG"             |"B_10_AVG"            |"B_11_AVG"            |"B_12_AVG"            |"B_13_AVG"            |"B_14_AVG"            |"B_15_AVG"             |"B_16_AVG"            |"B_17_AVG"           |"B_18_AVG"           |"B_19_AVG"             |"B_20_AVG"             |"B_21_AVG"             |"B_22_AVG"             |"B_23_A
091206192970276   |0.1558951586484909    |0.009329074062407017  |0.05080372095108032   |0.04947998747229576   |0.0026608817279338837  |0.009604280814528465  |NULL                 |0.6505489945411682   |0.0010209165047854185  |0.00933066289871931    |0.0005057862726971507  |0.0029128126334398985  |0.17822469770908356   |0.007645414676517248  |0.08704690635204315   |0.06244480237364769   |NULL                  |0.000000    |0.000000    |1.000000    |0.2076888382434845    |1.000000    |NULL        |0.1386105716228485    |0.0021728978026658297  |NULL        |0.150347501039505     |0.008805257268249989  |0.35595718026161194  |NULL                  |0.13389256596565247    |0.0024926522746682167  |NULL                 |0.23354580998420715   |0.6697776913642883    |NULL                  |0.006247104145586491   |NULL                  |1.000000    |0.20657280087471008   |0.14674873650074005   |NULL                 |0.3574308156967163    |0.4900786876678467    |0.015285507775843143  |0.0043024891056120396  |-127.000000  |NULL                   |0.25570613145828247    |0.010649274103343487  |0.009417248889803886   |NULL        |0.15212292969226837   |0.13913224637508392    |NULL        |NULL                  |0.003332601860165596   |0.002411049557849765   |NULL                |0.008135038428008556   |0.000000    |NULL                  |0.008531393483281136  |0.000000    |0.000000    |1.000000     |0.9566838145256042    |NULL         |1.000000     |NULL                  |-127.000000  |NULL                  |-127.000000  |NULL                  |NULL                  |-127.000000  |NULL                 |NULL                 |NULL                   |NULL                   |NULL                  |0.000000     |0.000000     |0.000000     |0.9837440848350525     |0.08183635771274567  |0.008146448992192745   |NULL         |-127.000000  |NULL         |0.000000     |0.00038026031688787043  |NULL                 |0.0008118687546811998  |0.00730455107986927    |0.4844352602958679   |NULL                |0.9576441645622253    |0.002540593734011054   |0.000000   |0.10117106884717941   |0.009641499258577824   |0.003747363109141588  |NULL                |0.009214826859533787  |0.007128431461751461   |0.0028284082654863596  |0.000000    |0.003131854347884655   |0.000000    |0.003915075678378344   |0.000000    |0.000000    |0.000000 ...
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
# Split the data into train and test sets
train_df, test_df = feature_df.random_split(weights=[0.9, 0.1], seed=0)

# %%
print((feature_df.count(), len(feature_df.columns)))
print((train_df.count(), len(train_df.columns)))
print((test_df.count(), len(test_df.columns)))
# Out:
# (458913, 471)
# (413064, 471)
# (45849, 471)

# %%
feature_cols = feature_df.columns

# %%
feature_cols = feature_df.columns
feature_cols.remove('"target"')
feature_cols.remove('"customer_ID"')
target_col = '"target"'

# %%
session.sql("USE DATABASE SCORED_MODEL").collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %%
session.sql("USE SCHEMA SCORED_MODEL").collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %%
session.sql("USE WAREHOUSE TRAINING_WH").collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %% [markdown]
# The cell below trains the model with the Snowpark ML LGBM Classifier. We call the .fit function over the train_df we just created above

# %%
lgbmodel = LGBMClassifier(
    input_cols=feature_cols, 
    label_cols=target_col, 
    output_cols='PREDICTION'
    )
lgbmodel.fit(train_df)
# Out:
# /Users/tbuchhorn/opt/anaconda3/envs/two-way-share-hol/lib/python3.10/site-packages/snowflake/ml/_internal/utils/snowpark_dataframe_utils.py:88: UserWarning: Warning: The Decimal(38, 6) data type is being automatically converted to DoubleType in the Snowpark DataFrame. This automatic conversion may lead to potential precision loss and rounding errors. If you wish to prevent this conversion, you should manually perform the necessary data type conversion.
#   warnings.warn(
# The following packages are not available in Snowflake: ['numpy==1.26.3'].
# If you are adding package(s) unavailable in Snowflake, it is highly recommended that you include the 'cache_path' configuration parameter in order to reduce latency.
# Package numpy(version 1.26.3) contains native code, switching to latest available version in Snowflake instead.
# /Users/tbuchhorn/opt/anaconda3/envs/two-way-share-hol/lib/python3.10/site-packages/snowflake/ml/model/_signatures/core.py:153: UserWarning: Warning: Type DecimalType(38, 6) is being automatically converted to DOUBLE in the Snowpark DataFrame. This automatic conversion may lead to potential precision loss and rounding errors. If you wish to prevent this conversion, you should manually perform the necessary data type conversion.
#   warnings.warn(

# %%
#Fix the fillna - maybe type float will help
scored_df = lgbmodel.predict(test_df.fillna(0.0))
# Out:
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "customer_ID", Type: StringType(16777216), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_33_MIN", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_36_MIN", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_112_MIN", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_128_MIN", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_140_MIN", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_27_MIN", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_8_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_30_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_32_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_33_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_38_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_54_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_66_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_86_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_94_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_96_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_103_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_112_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_114_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_117_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_120_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_126_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_128_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_129_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_135_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_140_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_2_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_15_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_17_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_21_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_22_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_24_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_27_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "S_6_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "S_18_AVG", Type: DecimalType(38, 6), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_8_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_30_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_33_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_38_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_63_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_64_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_112_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_116_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_117_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_126_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_128_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_135_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_140_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_17_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_27_MAX", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_8", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_30", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_32", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_33", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_36", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "B_38", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_54", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_63", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_64", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_86", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_96", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_112", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_114", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_120", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_126", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_127", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_130", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "D_140", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_2", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_4", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_13", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_15", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_19", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "R_27", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "S_6", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "S_19", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "S_20", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# Input value type doesn't match the target column data type, this replacement was skipped. Column Name: "target", Type: LongType(), Input Value: 0.0, Type: <class 'float'>
# /Users/tbuchhorn/opt/anaconda3/envs/two-way-share-hol/lib/python3.10/site-packages/snowflake/ml/_internal/utils/snowpark_dataframe_utils.py:88: UserWarning: Warning: The Decimal(38, 6) data type is being automatically converted to DoubleType in the Snowpark DataFrame. This automatic conversion may lead to potential precision loss and rounding errors. If you wish to prevent this conversion, you should manually perform the necessary data type conversion.
#   warnings.warn(
# The version of package 'numpy' in the local environment is 1.26.3, which does not fit the criteria for the requirement 'numpy==1.26.2'. Your UDF might not work when the package version is different between the server and your local environment.

# %%
# Get metrics on the scored model
print('Acccuracy:', accuracy_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))
print('Precision:', precision_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))
print('Recall:', recall_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))
print('F1:', f1_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))

# Obtaining and plotting a simple confusion matrix
cf_matrix = confusion_matrix(df=scored_df, y_true_col_name='"target"', y_pred_col_name='PREDICTION')

sns.heatmap(cf_matrix, annot=True, fmt='.0f', cmap='Blues')
# Out:
# Acccuracy: 0.899125
# Precision: 0.7954907584448694
# The version of package 'numpy' in the local environment is 1.26.3, which does not fit the criteria for the requirement 'numpy'. Your UDF might not work when the package version is different between the server and your local environment.
# DataFrame.flatten() is deprecated since 0.7.0. Use `DataFrame.join_table_function()` instead.
# Recall: 0.8291123474217388
# The version of package 'numpy' in the local environment is 1.26.3, which does not fit the criteria for the requirement 'numpy'. Your UDF might not work when the package version is different between the server and your local environment.
# F1: 0.811953649115674
# The version of package 'numpy' in the local environment is 1.26.3, which does not fit the criteria for the requirement 'numpy'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'numpy' in the local environment is 1.26.3, which does not fit the criteria for the requirement 'numpy'. Your UDF might not work when the package version is different between the server and your local environment.
# <Axes: >

# %% [markdown]
# We are happy with the metrics of the model above, so we can persist the scored trained dataset (if we want to use it later), and proceed to registering the model

# %% [markdown]
# ## Model Registration (Vectorized UDF)

# %%
# Create a stage for the model if it doesnt exist
session.sql("CREATE STAGE IF NOT EXISTS MODEL_ASSETS").collect()
# Out:
# [Row(status='Stage area MODEL_ASSETS successfully created.')]

# %%
# For this method, we convert the model to a local one, so we can stage it and deploy to Snowflake
lgbmodel_local = lgbmodel.to_lightgbm()

# %%
import joblib

# Let's save our model first
MODEL_FILE = 'model.joblib'
joblib.dump(lgbmodel_local, MODEL_FILE) # we are just pickling it locally first

# You can also save the pickled object into the stage we created earlier
session.file.put(MODEL_FILE, "@MODEL_ASSETS", overwrite=True)
# Out:
# [PutResult(source='model.joblib', target='model.joblib.gz', source_size=387919, target_size=171696, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message='')]

# %%
import cachetools
from snowflake.snowpark.functions import udf
# Cache the model load to optimize inference
@cachetools.cached(cache={})
def load_model(filename):
    import joblib
    import sys
    import os

    IMPORT_DIRECTORY_NAME = "snowflake_import_directory"
    import_dir = sys._xoptions[IMPORT_DIRECTORY_NAME]

    if import_dir:
        with open(os.path.join(import_dir, filename), 'rb') as file:
            m = joblib.load(file)
            return m

# Register the UDF via decorator
@udf(name='batch_predict_cc_default', 
     session=session, 
     replace=True, 
     is_permanent=True, 
     stage_location='@MODEL_ASSETS',
     input_types=[F.FloatType()]*len(feature_cols),
     return_type=F.FloatType(),
     imports=['@MODEL_ASSETS/model.joblib.gz'],
     packages=['pandas','joblib','cachetools','lightgbm', 'numpy', 'scikit-learn'])
def batch_predict_cc_default(test_df: pd.DataFrame) -> pd.Series:
    # Need to name the columns because column names aren't passed in to this function
    test_df.columns = feature_cols
    model = load_model('model.joblib.gz')
    return model.predict(test_df) # This is using the XGBoost library's model.predict(), not Snowpark ML's
# Out:
# The version of package 'numpy' in the local environment is 1.26.3, which does not fit the criteria for the requirement 'numpy'. Your UDF might not work when the package version is different between the server and your local environment.

# %%
# This cell runs the model in a secure python sandbox in Snowflake
from snowflake.snowpark.functions import call_udf
scored_data = test_df.select('"customer_ID"', call_udf("batch_predict_cc_default", [F.col(c) for c in feature_cols]).alias('Prediction'))

# %%
# Persist the results to a table
scored_data.write.save_as_table(table_name='UDF_TEST_SCORED', mode='overwrite')

# %% [markdown]
# Now we have a UDF deployed in our Snowflake account called "batch_predict_cc_default" that we can use on incoming data.

# %% [markdown]
# ## Productionize the Model

# %% [markdown]
# We have tested the feature engineering pipeline and the model performance, so we will now productionise the scoring of newly incoming data by leveraging Streams and Tasks. The Tasks will contain Stored Procedures which hold the logic for feature engineering and scoring models.

# %% [markdown]
# These can be create from Notebooks using Snowpark functions, but for this HOL we will switch back to Snowsight to demonstrate how it can be done from a SQL Worksheet.

# %% [markdown]
# Proceed to step 9 and stay in the Zamboni account
