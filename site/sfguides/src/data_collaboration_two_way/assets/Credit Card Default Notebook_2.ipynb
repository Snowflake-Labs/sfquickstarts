# %% [markdown]
# # Environment Setup

# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.version import VERSION
import snowflake.snowpark as snp
import snowflake.snowpark.functions as F
import snowflake.snowpark.types as T
import snowflake.snowpark.window as W

import pandas as pd
import json
import seaborn as sns

from snowflake.ml.modeling.lightgbm import LGBMClassifier
from snowflake.ml.modeling.metrics import *
from snowflake.ml.modeling.impute import SimpleImputer

# %% [markdown]
# ## Create Snowpark Session

# %%
# Make a Snowpark Connection
# Edit the connection.json before creating the session object below
# Create Snowflake Session object

connection_parameters = json.load(open('connection.json'))
session = Session.builder.configs(connection_parameters).create()
#session.custom_package_usage_config = {"enabled": True}
#session.add_packages(["numpy==1.26.3"])

snowflake_environment = session.sql('SELECT current_user(), current_version()').collect()
snowpark_version = VERSION

# Current Environment Details
print('\nConnection Established with the following parameters:')
print('User                        : {}'.format(snowflake_environment[0][0]))
print('Role                        : {}'.format(session.get_current_role()))
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
print('Warehouse                   : {}'.format(session.get_current_warehouse()))
print('Snowflake version           : {}'.format(snowflake_environment[0][1]))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# Connection Established with the following parameters:
# User                        : JOHN
# Role                        : "ACCOUNTADMIN"
# Database                    : "SCORED_MODEL"
# Schema                      : "SCORED_MODEL"
# Warehouse                   : "QUERY_WH"
# Snowflake version           : 8.3.1
# Snowpark for Python version : 1.11.1

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# This notebook is based on the worksheet found here (https://www.kaggle.com/code/ambrosm/amex-lightgbm-quickstart), with some modifications. The dataset has multiple values per customer ID, so we will undertake some feature engineering to find the mean, standard deviation, min, max and last values of each customer ID, so we have features and customer ID as a unique key.

# %%
#Create Snowpark df from shared data
training_df = session.table('"CC_DEFAULT_TRAINING_DATA"."DATA_SHARING_DEMO"."CC_DEFAULT_TRAINING_DATA"')

# %%
# Check number of rows (5,531,451 rows)
training_df.count()
# Out:
# 5531451

# %%
# Check first 5 rows
training_df.show(5)
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"D_50"  |"D_51"                  |"B_9"                 |"R_3"                  |"D_52"                |"P_3"                |"B_10"                |"D_53"               |"S_5"                   |"B_11"                 |"S_6"  |"D_54"  |"R_4"  |"S_7"                |"B_12"                |"S_8"                 |"D_55"              |"D_56"  |"B_13"                 |"R_5"                  |"D_58"               |"S_9"  |"B_14"                 |"D_59"               |"R_27"  |"B_38"  |"D_108"  |"D_109"  |"D_110"  |"D_111"  |"B_39"  |"D_112"  |"B_40"               |"S_27"                 |"D_113"                |"D_114"  |"D_115"             |"D_116"  |"D_117"  |"D_118"             |"D_119"             |"D_120"  |"D_121"             |"D_122"              |"D_123"                |"D_124"              |"D_125"                |"D_126"  |"S_2"             |"P_2"                 |"D_39"                 |"B_1"                 |"B_2"                 |"R_1"                  |"S_3"                |"D_41"               |"B_3"                  |"D_42"  |"D_43"  |"D_44"               |"B_4"                |"D_45"               |"B_5"                  |"R_2"  |"D_46"               |"D_47"               |"D_48"              |"D_49"  |"B_6"                  |"B_7"                |"B_8"  |"S_15"               |"B_23"
|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# For the next section, we are going to perform feature engineering create three groups of features:
# - Selected features averaged over all statements of a customer
# - The minimum or maximum of selected features over all statements of a customer
# - Selected features taken from the last statement of a customer

# %%
# The following cells create the average numerical values for selected features per customer
features_avg = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_8', 'B_9', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_20', 'B_21', 'B_22', 'B_23', 'B_24', 'B_25', 'B_28', 'B_29', 'B_30', 'B_32', 'B_33', 'B_37', 'B_38', 'B_39', 'B_40', 'B_41', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_50', 'D_51', 'D_53', 'D_54', 'D_55', 'D_58', 'D_59', 'D_60', 'D_61', 'D_62', 'D_65', 'D_66', 'D_69', 'D_70', 'D_71', 'D_72', 'D_73', 'D_74', 'D_75', 'D_76', 'D_77', 'D_78', 'D_80', 'D_82', 'D_84', 'D_86', 'D_91', 'D_92', 'D_94', 'D_96', 'D_103', 'D_104', 'D_108', 'D_112', 'D_113', 'D_114', 'D_115', 'D_117', 'D_118', 'D_119', 'D_120', 'D_121', 'D_122', 'D_123', 'D_124', 'D_125', 'D_126', 'D_128', 'D_129', 'D_131', 'D_132', 'D_133', 'D_134', 'D_135', 'D_136', 'D_140', 'D_141', 'D_142', 'D_144', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_2', 'R_3', 'R_7', 'R_8', 'R_9', 'R_10', 'R_11', 'R_14', 'R_15', 'R_16', 'R_17', 'R_20', 'R_21', 'R_22', 'R_24', 'R_26', 'R_27', 'S_3', 'S_5', 'S_6', 'S_7', 'S_9', 'S_11', 'S_12', 'S_13', 'S_15', 'S_16', 'S_18', 'S_22', 'S_23', 'S_25', 'S_26']

# %%
feat = [F.col(c) for c in features_avg]

# %%
exprs = {x: "avg" for x in features_avg}

# %%
df_avg = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs)
          .rename({F.col(f"AVG({f})"): f"{f}_avg" for f in features_avg})
         )

# %%
df_avg.count()
# Out:
# 458913

# %%
# The following cells create the minimum numerical values for selected features per customer
features_min = ['B_2', 'B_4', 'B_5', 'B_9', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_19', 'B_20', 'B_28', 'B_29', 'B_33', 'B_36', 'B_42', 'D_39', 'D_41', 'D_42', 'D_45', 'D_46', 'D_48', 'D_50', 'D_51', 'D_53', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_62', 'D_70', 'D_71', 'D_74', 'D_75', 'D_78', 'D_83', 'D_102', 'D_112', 'D_113', 'D_115', 'D_118', 'D_119', 'D_121', 'D_122', 'D_128', 'D_132', 'D_140', 'D_141', 'D_144', 'D_145', 'P_2', 'P_3', 'R_1', 'R_27', 'S_3', 'S_5', 'S_7', 'S_9', 'S_11', 'S_12', 'S_23', 'S_25']

# %%
exprs_min = {x: "min" for x in features_min}

# %%
df_min = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs_min)
          .rename({F.col(f"MIN({f})"): f"{f}_min" for f in features_min})
         )

# %%
df_min.count()
# Out:
# 458913

# %%
# The following cells create the maximum numerical values for selected features per customer
features_max = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_7', 'B_8', 'B_9', 'B_10', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_21', 'B_23', 'B_24', 'B_25', 'B_29', 'B_30', 'B_33', 'B_37', 'B_38', 'B_39', 'B_40', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_52', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_61', 'D_63', 'D_64', 'D_65', 'D_70', 'D_71', 'D_72', 'D_73', 'D_74', 'D_76', 'D_77', 'D_78', 'D_80', 'D_82', 'D_84', 'D_91', 'D_102', 'D_105', 'D_107', 'D_110', 'D_111', 'D_112', 'D_115', 'D_116', 'D_117', 'D_118', 'D_119', 'D_121', 'D_122', 'D_123', 'D_124', 'D_125', 'D_126', 'D_128', 'D_131', 'D_132', 'D_133', 'D_134', 'D_135', 'D_136', 'D_138', 'D_140', 'D_141', 'D_142', 'D_144', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_3', 'R_5', 'R_6', 'R_7', 'R_8', 'R_10', 'R_11', 'R_14', 'R_17', 'R_20', 'R_26', 'R_27', 'S_3', 'S_5', 'S_7', 'S_8', 'S_11', 'S_12', 'S_13', 'S_15', 'S_16', 'S_22', 'S_23', 'S_24', 'S_25', 'S_26', 'S_27']

# %%
exprs_max = {x: "max" for x in features_max}

# %%
df_max = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs_max)
          .rename({F.col(f"MAX({f})"): f"{f}_max" for f in features_max})
         )

# %%
df_max.count()
# Out:
# 458913

# %%
# The following cells create the last numerical values for selected features per customer, with S_2 being the date field.
features_last = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_7', 'B_8', 'B_9', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_20', 'B_21', 'B_22', 'B_23', 'B_24', 'B_25', 'B_26', 'B_28', 'B_29', 'B_30', 'B_32', 'B_33', 'B_36', 'B_37', 'B_38', 'B_39', 'B_40', 'B_41', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_51', 'D_52', 'D_53', 'D_54', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_61', 'D_62', 'D_63', 'D_64', 'D_65', 'D_69', 'D_70', 'D_71', 'D_72', 'D_73', 'D
.000000     |0.20497100055217743   |-63.000000   |0.10154989361763      |-64.000000   |0.06985246390104294   |0.06952269375324249   |-63.000000   |0.2613885700702667   |0.15208302438259125  |0.0020702569745481014  |0.23057982325553894  |0.001001009251922369   |0.000000     |0.000000     |0.000000     |0.004900971776805818   |NULL         |0.0033333075552945957  |NULL                 |-127.000000  |NULL                 |0.000000     |0.004820885835215449   |NULL                |0.005806513829156756   |0.002575297898147255   |0.23739803582429886  |NULL                |0.9645430445671082    |0.2563668576767668     |0.500000   |0.20652784407138824   |0.0047207605093717575  |0.00677084643393755   |0.33823904395103455  |0.006924396380782127   |0.005888632382266223   |0.18208888079971075   |0.000000    |0.5072937309741974    |0.000000    |0.505948965204879 ...
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
num_cols = feature_df.columns
# Imputation of Numeric Cols
my_imputer = SimpleImputer(input_cols= num_cols,
                           output_cols= num_cols,
                           strategy='most_frequent')
df_prepared = my_imputer.fit(feature_df).transform(feature_df)
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/_internal/telemetry.py:358, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     357 try:
# --> 358     res = func(*args, **kwargs)
#     359 except Exception as e:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/modeling/impute/simple_imputer.py:285, in SimpleImputer.fit(self, dataset)
#     284     dataset_copy = dataset_copy.na.replace(self.missing_values, None)
# --> 285 _computed_states = self._compute(dataset_copy, self.input_cols, states=[state])
#     286 for input_col in self.input_cols:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/modeling/framework/base.py:471, in BaseEstimator._compute(self, dataset, cols, states)
#     469     return res
# --> 471 _results = parallelize.map_dataframe_by_column(
#     472     df=dataset,
#     473     cols=cols,
#     474     map_func=_compute_on_partition,
#     475     partition_size=40,
#     476     statement_params=telemetry.get_statement_params(PROJECT, SUBPROJECT, self.__class__.__name__),
#     477 )
#     479 computed_dict: Dict[str, Dict[str, Union[int, float, str]]] = {}
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/_internal/utils/parallelize.py:90, in map_dataframe_by_column(df, cols, map_func, partition_size, statement_params)
#      89 # Collect the results of the first n-1 partitions, removing the partition_id column
# ---> 90 unioned_result = unioned_df.collect(statement_params=statement_params) if unioned_df is not None else []
#      91 for row in unioned_result:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/telemetry.py:139, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     138 with args[0]._session.query_history() as query_history:
# --> 139     result = func(*args, **kwargs)
#     140 plan = args[0]._select_statement or args[0]._plan
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:587, in DataFrame.collect(self, statement_params, block, log_on_exception, case_sensitive)
#     573 """Executes the query representing this DataFrame and returns the result as a
#     574 list of :class:`Row` objects.
#     575
#    (...)
#     585     :meth:`collect_nowait()`
#     586 """
# --> 587 return self._internal_collect_with_tag_no_telemetry(
#     588     statement_params=statement_params,
#     589     block=block,
#     590     log_on_exception=log_on_exception,
#     591     case_sensitive=case_sensitive,
#     592 )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:634, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive)
#     622 def _internal_collect_with_tag_no_telemetry(
#     623     self,
#     624     *,
#    (...)
#     632     # we should always call this method instead of collect(), to make sure the
#     633     # query tag is set properly.
# --> 634     return self._session._conn.execute(
#     635         self._plan,
#     636         block=block,
#     637         data_type=data_type,
#     638         _statement_params=create_or_update_statement_params_with_query_tag(
#     639             statement_params or self._statement_params,
#     640             self._session.query_tag,
#     641             SKIP_LEVELS_THREE,
#     642         ),
#     643         log_on_exception=log_on_exception,
#     644         case_sensitive=case_sensitive,
#     645     )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:472, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     469     raise NotImplementedError(
#     470         "Async query is not supported in stored procedure yet"
#     471     )
# --> 472 result_set, result_meta = self.get_result_set(
#     473     plan,
#     474     to_pandas,
#     475     to_iter,
#     476     **kwargs,
#     477     block=block,
#     478     data_type=data_type,
#     479     log_on_exception=log_on_exception,
#     480     case_sensitive=case_sensitive,
#     481 )
#     482 if not block:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:185, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     182 ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     183     e
#     184 )
# --> 185 raise ne.with_traceback(tb) from None
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:116, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     115 try:
# --> 116     return func(*args, **kwargs)
#     117 except snowflake.connector.errors.ProgrammingError as e:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:573, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     572     final_query = final_query.replace(holder, id_)
# --> 573 result = self.run_query(
#     574     final_query,
#     575     to_pandas,
#     576     to_iter and (i == len(plan.queries) - 1),
#     577     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     578     block=not is_last,
#     579     data_type=data_type,
#     580     async_job_plan=plan,
#     581     log_on_exception=log_on_exception,
#     582     case_sensitive=case_sensitive,
#     583     params=query.params,
#     584     **kwargs,
#     585 )
#     586 placeholders[query.query_id_place_holder] = (
#     587     result["sfqid"] if not is_last else result.query_id
#     588 )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:123, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     122 except Exception as ex:
# --> 123     raise ex
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:117, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     116 try:
# --> 117     return func(*args, **kwargs)
#     118 except ReauthenticationRequest as ex:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:387, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, **kwargs)
#     386         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 387     raise ex
#     389 # fetch_pandas_all/batches() only works for SELECT statements
#     390 # We call fetchall() if fetch_pandas_all/batches() fails,
#     391 # because when the query plan has multiple queries, it will
#     392 # have non-select statements, and it shouldn't fail if the user
#     393 # calls to_pandas() to execute the query.
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:368, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, **kwargs)
#     367 if block:
# --> 368     results_cursor = self._cursor.execute(query, params=params, **kwargs)
#     369     self.notify_query_listeners(
#     370         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     371     )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/cursor.py:920, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#     919     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 920     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     921 return self
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     274 """Error handler wrapper that calls the errorhandler method.
#     275
#     276 Args:
#    (...)
#     287     exception to the first handler in that order.
#     288 """
# --> 290 handed_over = Error.hand_to_other_handler(
#     291     connection,
#     292     cursor,
#     293     error_class,
#     294     error_value,
#     295 )
#     296 if not handed_over:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     344 cursor.messages.append((error_class, error_value))
# --> 345 cursor.errorhandler(connection, cursor, error_class, error_value)
#     346 return True
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# SnowparkSQLException: (1304): 01b1e617-3202-3a07-0000-0001994e81e5: 100038 (22018): Numeric value '75419191bc285b376a281a4d3e5028a487a43aa122e3d2bd7f2395eed545b253' is not recognized
#
# The above exception was the direct cause of the following exception:
#
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[36], line 6
#       2 # Imputation of Numeric Cols
#       3 my_imputer = SimpleImputer(input_cols= num_cols,
#       4                            output_cols= num_cols,
#       5                            strategy='most_frequent')
# ----> 6 df_prepared = my_imputer.fit(feature_df).transform(feature_df)
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/_internal/telemetry.py:380, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     378         raise me.original_exception from None
#     379     else:
# --> 380         raise me.original_exception from e
#     381 else:
#     382     return update_stmt_params_if_snowpark_df(res, statement_params)
#
# SnowparkSQLException: (1300) (1304): 01b1e617-3202-3a07-0000-0001994e81e5: 100038 (22018): Numeric value '75419191bc285b376a281a4d3e5028a487a43aa122e3d2bd7f2395eed545b253' is not recognized

# %%
df_prepared.show()

# %%
# Split the data into train and test sets
train_df, test_df = feature_df.random_split(weights=[0.9, 0.1], seed=0)

# %%
print((feature_df.count(), len(feature_df.columns)))
print((train_df.count(), len(train_df.columns)))
print((test_df.count(), len(test_df.columns)))
# Out:
# (458913, 471)
# (413064, 471)
# (45849, 471)

# %%
feature_cols = feature_df.columns

# %%
feature_cols = feature_df.columns
feature_cols.remove('"target"')
feature_cols.remove('"customer_ID"')
target_col = '"target"'

# %%
session.sql("USE DATABASE SCORED_MODEL").collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %%
session.sql("USE SCHEMA SCORED_MODEL").collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %%
session.sql("USE WAREHOUSE TRAINING_WH").collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %% [markdown]
# The cell below trains the model with the Snowpark ML LGBM Classifier. We call the .fit function over the train_df we just created above

# %%
# Error TypeError: 'NoneType' object is not callable

lgbmodel = LGBMClassifier(
    input_cols=feature_cols, 
    label_cols=target_col, 
    output_cols='PREDICTION'
    )
lgbmodel.fit(train_df)
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/_internal/telemetry.py:358, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     357 try:
# --> 358     res = func(*args, **kwargs)
#     359 except Exception as e:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/modeling/lightgbm/lgbm_classifier.py:288, in LGBMClassifier.fit(self, dataset)
#     277 model_trainer = ModelTrainerBuilder.build(
#     278     estimator=self._sklearn_object,
#     279     dataset=dataset,
#    (...)
#     286     batch_size=self._batch_size,
#     287 )
# --> 288 self._sklearn_object = model_trainer.train()
#     289 self._is_fitted = True
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/modeling/_internal/snowpark_trainer.py:329, in SnowparkModelTrainer.train(self)
#     325         raise exceptions.SnowflakeMLException(
#     326             error_code=error_codes.NOT_FOUND,
#     327             original_exception=RuntimeError(modeling_error_messages.ATTRIBUTE_NOT_SET.format("label_cols")),
#     328         ) from e
# --> 329     raise e
#     331 if "|" in sproc_export_file_name:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/modeling/_internal/snowpark_trainer.py:313, in SnowparkModelTrainer.train(self)
#     312 try:
# --> 313     sproc_export_file_name: str = fit_wrapper_sproc(
#     314         self.session,
#     315         queries,
#     316         stage_transform_file_name,
#     317         stage_result_file_name,
#     318         self.input_cols,
#     319         self.label_cols,
#     320         self.sample_weight_col,
#     321         statement_params,
#     322     )
#     323 except snowpark_exceptions.SnowparkClientException as e:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/stored_procedure.py:109, in StoredProcedure.__call__(self, session, *args)
#     108 else:
# --> 109     return session._call(
#     110         self.name, *args, is_return_table=self._is_return_table
#     111     )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/session.py:2630, in Session._call(self, sproc_name, statement_params, is_return_table, log_on_exception, *args)
#    2629     return df
# -> 2630 return df.collect(statement_params=statement_params)[0][0]
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/telemetry.py:139, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     138 with args[0]._session.query_history() as query_history:
# --> 139     result = func(*args, **kwargs)
#     140 plan = args[0]._select_statement or args[0]._plan
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:587, in DataFrame.collect(self, statement_params, block, log_on_exception, case_sensitive)
#     573 """Executes the query representing this DataFrame and returns the result as a
#     574 list of :class:`Row` objects.
#     575
#    (...)
#     585     :meth:`collect_nowait()`
#     586 """
# --> 587 return self._internal_collect_with_tag_no_telemetry(
#     588     statement_params=statement_params,
#     589     block=block,
#     590     log_on_exception=log_on_exception,
#     591     case_sensitive=case_sensitive,
#     592 )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:634, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive)
#     622 def _internal_collect_with_tag_no_telemetry(
#     623     self,
#     624     *,
#    (...)
#     632     # we should always call this method instead of collect(), to make sure the
#     633     # query tag is set properly.
# --> 634     return self._session._conn.execute(
#     635         self._plan,
#     636         block=block,
#     637         data_type=data_type,
#     638         _statement_params=create_or_update_statement_params_with_query_tag(
#     639             statement_params or self._statement_params,
#     640             self._session.query_tag,
#     641             SKIP_LEVELS_THREE,
#     642         ),
#     643         log_on_exception=log_on_exception,
#     644         case_sensitive=case_sensitive,
#     645     )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:472, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     469     raise NotImplementedError(
#     470         "Async query is not supported in stored procedure yet"
#     471     )
# --> 472 result_set, result_meta = self.get_result_set(
#     473     plan,
#     474     to_pandas,
#     475     to_iter,
#     476     **kwargs,
#     477     block=block,
#     478     data_type=data_type,
#     479     log_on_exception=log_on_exception,
#     480     case_sensitive=case_sensitive,
#     481 )
#     482 if not block:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:185, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     182 ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     183     e
#     184 )
# --> 185 raise ne.with_traceback(tb) from None
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:116, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     115 try:
# --> 116     return func(*args, **kwargs)
#     117 except snowflake.connector.errors.ProgrammingError as e:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:573, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     572     final_query = final_query.replace(holder, id_)
# --> 573 result = self.run_query(
#     574     final_query,
#     575     to_pandas,
#     576     to_iter and (i == len(plan.queries) - 1),
#     577     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     578     block=not is_last,
#     579     data_type=data_type,
#     580     async_job_plan=plan,
#     581     log_on_exception=log_on_exception,
#     582     case_sensitive=case_sensitive,
#     583     params=query.params,
#     584     **kwargs,
#     585 )
#     586 placeholders[query.query_id_place_holder] = (
#     587     result["sfqid"] if not is_last else result.query_id
#     588 )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:123, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     122 except Exception as ex:
# --> 123     raise ex
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:117, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     116 try:
# --> 117     return func(*args, **kwargs)
#     118 except ReauthenticationRequest as ex:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:387, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, **kwargs)
#     386         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 387     raise ex
#     389 # fetch_pandas_all/batches() only works for SELECT statements
#     390 # We call fetchall() if fetch_pandas_all/batches() fails,
#     391 # because when the query plan has multiple queries, it will
#     392 # have non-select statements, and it shouldn't fail if the user
#     393 # calls to_pandas() to execute the query.
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:368, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, **kwargs)
#     367 if block:
# --> 368     results_cursor = self._cursor.execute(query, params=params, **kwargs)
#     369     self.notify_query_listeners(
#     370         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     371     )
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/cursor.py:920, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#     919     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 920     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     921 return self
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     274 """Error handler wrapper that calls the errorhandler method.
#     275
#     276 Args:
#    (...)
#     287     exception to the first handler in that order.
#     288 """
# --> 290 handed_over = Error.hand_to_other_handler(
#     291     connection,
#     292     cursor,
#     293     error_class,
#     294     error_value,
#     295 )
#     296 if not handed_over:
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     344 cursor.messages.append((error_class, error_value))
# --> 345 cursor.errorhandler(connection, cursor, error_class, error_value)
#     346 return True
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/connector/errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# SnowparkSQLException: (1304): 01b1e616-3202-3844-0000-0001994eb1a9: 100357 (P0000): Python Interpreter Error:
# Traceback (most recent call last):
#   File "/home/udf/26824244/udf_py_1122753591.zip/udf_py_1122753591.py", line 76, in compute
#     return func(session,arg1,arg2,arg3,arg4,arg5,arg6,arg7)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tbuchhorn/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/modeling/_internal/snowpark_trainer.py", line 226, in fit_wrapper_function
#   File "/usr/lib/python_udf/a5b0d72e35bafbb9825066cf2ff3d035a6bd4a07b789f6e132f80ad945a8c509/lib/python3.11/site-packages/lightgbm/sklearn.py", line 1096, in fit
#     _LGBMAssertAllFinite(y)
# TypeError: 'NoneType' object is not callable
#  in function SNOWPARK_TEMP_PROCEDURE_1LIA1BYD8D with handler udf_py_1122753591.compute
#
# The above exception was the direct cause of the following exception:
#
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[35], line 8
#       1 # Error TypeError: 'NoneType' object is not callable
#       3 lgbmodel = LGBMClassifier(
#       4     input_cols=feature_cols,
#       5     label_cols=target_col,
#       6     output_cols='PREDICTION'
#       7     )
# ----> 8 lgbmodel.fit(train_df)
#
# File ~/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/_internal/telemetry.py:380, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     378         raise me.original_exception from None
#     379     else:
# --> 380         raise me.original_exception from e
#     381 else:
#     382     return update_stmt_params_if_snowpark_df(res, statement_params)
#
# SnowparkSQLException: (1300) (1304): 01b1e616-3202-3844-0000-0001994eb1a9: 100357 (P0000): Python Interpreter Error:
# Traceback (most recent call last):
#   File "/home/udf/26824244/udf_py_1122753591.zip/udf_py_1122753591.py", line 76, in compute
#     return func(session,arg1,arg2,arg3,arg4,arg5,arg6,arg7)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tbuchhorn/opt/anaconda3/envs/snowpark-ml-lightgbm/lib/python3.11/site-packages/snowflake/ml/modeling/_internal/snowpark_trainer.py", line 226, in fit_wrapper_function
#   File "/usr/lib/python_udf/a5b0d72e35bafbb9825066cf2ff3d035a6bd4a07b789f6e132f80ad945a8c509/lib/python3.11/site-packages/lightgbm/sklearn.py", line 1096, in fit
#     _LGBMAssertAllFinite(y)
# TypeError: 'NoneType' object is not callable
#  in function SNOWPARK_TEMP_PROCEDURE_1LIA1BYD8D with handler udf_py_1122753591.compute

# %%
#Fix the fillna - maybe type float will help
scored_df = lgbmodel.predict(test_df.fillna(0.0))

# %%
print('Acccuracy:', accuracy_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))
print('Precision:', precision_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))
print('Recall:', recall_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))
print('F1:', f1_score(df=scored_df, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))

# Obtaining and plotting a simple confusion matrix
cf_matrix = confusion_matrix(df=scored_df, y_true_col_name='"target"', y_pred_col_name='PREDICTION')

sns.heatmap(cf_matrix, annot=True, fmt='.0f', cmap='Blues')

# %% [markdown]
# We are happy with the metrics of the model above, so we can persist the scored trained dataset (if we want to use it later), and proceed to registering the model

# %%
scored_df.write.save_as_table(table_name='CC_DEFAULT_RISK_TEST_SCORED', mode='overwrite')
session.table('CC_DEFAULT_RISK_TEST_SCORED').show()

# %%
# Plot feature importance (only local)
feat_importance = pd.DataFrame(lgbmodel.feature_importances_,lgbmodel.feature_name_,columns=['FeatImportance'])
feat_importance.sort_values('FeatImportance').tail(10).plot.barh(y='FeatImportance', figsize=(5,15))

# %% [markdown]
# ## Model Registration

# %% [markdown]
# Now we are happy with the mode we have trained, we can simply call the predict function on any new data that is sent from our client, the bank. Previously, we would have used UDFs to perform this task, but with ML on Snowpark, this has been greatly simplified. See more here: https://medium.com/snowflake/ml-on-snowflake-at-scale-with-snowpark-python-and-snowpark-ml-part-2-6491d72a9903

# %%
#If you do not have a model registry, create one
# Create a registry and log the model
registry = model_registry.ModelRegistry(session=session, database_name="MODEL_REGISTRY", create_if_not_exists=True)

# %%
from snowflake.ml.registry import model_registry

registry = model_registry.ModelRegistry(session=session
                                        , database_name="MODEL_REGISTRY")

model_id = registry.log_model(model=lgbmodel, model_name="cc_default_risk_model"
                              , model_version="1"
                              , tags={"stage": "testing"
                                 , "classifier_type": "lightgbm.LGBMClassifier"})

model = model_registry.ModelReference(registry=registry
                                      , model_name="cc_default_risk_model"
                                      , model_version="1")

#model.set_metric(metric_name="mean_squared_error", metric_value=mse)
#model.set_metric(metric_name="mean_absolute_error", metric_value=mab)
#model.set_metric(metric_name="r2_score", metric_value=r2)

# %%
registry.set_metric(model_name="cc_default_risk_model", model_version="1", metric_name="accuracy_score", metric_value=accuracy_score)

# %%
# Let's confirm it was added
registry.list_models().to_pandas()

# %%
# Pick a deployment name and deploy
model_name = "cc_default_risk_model"
model_version = "1"
model_deployment_name = model_name + f"{model_version}" + "_UDF"

registry.deploy(model_name=model_name,
                model_version=model_version,
                deployment_name=model_deployment_name, 
                target_method="predict", 
                permanent=True, 
                options={"relax_version": True})

# %% [markdown]
# ## Alternate Model Deployment
# The alternative is to deploy via a vectorized UDF

# %%
# Create a stage for the model if it doesnt exist
session.sql("CREATE STAGE IF NOT EXISTS MODEL_ASSETS").collect()

# %%
# For this method, we convert the model to a local one, so we can stage it and deploy to Snowflake
lgbmodel_local = lgbmodel.to_lightgbm()

# %%
import joblib

# Let's save our model first
MODEL_FILE = 'model.joblib'
joblib.dump(lgbmodel_local, MODEL_FILE) # we are just pickling it locally first

# You can also save the pickled object into the stage we created earlier
session.file.put(MODEL_FILE, "@MODEL_ASSETS", overwrite=True)

# %%
import cachetools
from snowflake.snowpark.functions import udf
# Cache the model load to optimize inference
@cachetools.cached(cache={})
def load_model(filename):
    import joblib
    import sys
    import os

    IMPORT_DIRECTORY_NAME = "snowflake_import_directory"
    import_dir = sys._xoptions[IMPORT_DIRECTORY_NAME]

    if import_dir:
        with open(os.path.join(import_dir, filename), 'rb') as file:
            m = joblib.load(file)
            return m

# Register the UDF via decorator
@udf(name='batch_predict_cc_default', 
     session=session, 
     replace=True, 
     is_permanent=True, 
     stage_location='@MODEL_ASSETS',
     input_types=[F.FloatType()]*len(feature_cols),
     return_type=F.FloatType(),
     imports=['@MODEL_ASSETS/model.joblib.gz'],
     packages=['pandas','joblib','cachetools','lightgbm', 'numpy', 'scikit-learn'])
def batch_predict_cc_default(test_df: pd.DataFrame) -> pd.Series:
    # Need to name the columns because column names aren't passed in to this function
    test_df.columns = feature_cols
    model = load_model('model.joblib.gz')
    return model.predict(test_df) # This is using the XGBoost library's model.predict(), not Snowpark ML's

# %%
from snowflake.snowpark.functions import call_udf
scored_data = test_df.select('"customer_ID"', call_udf("batch_predict_cc_default", [F.col(c) for c in feature_cols]).alias('Prediction'))

# %%
scored_data.write.save_as_table(table_name='UDF_TEST_SCORED', mode='overwrite')

# %%
test_df_w_preds = test_df.with_column('PREDICTION', batch_predict_cc_default(*feature_cols))
test_df_w_preds.show()

# %%
# Test for accuracy
print('Acccuracy:', accuracy_score(df=test_df_w_preds, y_true_col_names='"target"', y_pred_col_names='PREDICTION'))

# %% [markdown]
# Now we have a UDF deployed in our Snowflake account called "batch_predict_cc_default" that we can use on incoming data.

# %%
# FEATURE ENGINEERING LOGIC
import snowflake.snowpark
from snowflake.snowpark.functions import sproc

session.add_packages('snowflake-snowpark-python')

def feature_transform(session: snowflake.snowpark.Session, raw_table: str, output_table: str) -> str:
    training_df = session.table(raw_table)
    # Feature engineer raw input
    #Average
    features_avg = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_8', 'B_9', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_20', 'B_21', 'B_22', 'B_23', 'B_24', 'B_25', 'B_28', 'B_29', 'B_30', 'B_32', 'B_33', 'B_37', 'B_38', 'B_39', 'B_40', 'B_41', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_50', 'D_51', 'D_53', 'D_54', 'D_55', 'D_58', 'D_59', 'D_60', 'D_61', 'D_62', 'D_65', 'D_66', 'D_69', 'D_70', 'D_71', 'D_72', 'D_73', 'D_74', 'D_75', 'D_76', 'D_77', 'D_78', 'D_80', 'D_82', 'D_84', 'D_86', 'D_91', 'D_92', 'D_94', 'D_96', 'D_103', 'D_104', 'D_108', 'D_112', 'D_113', 'D_114', 'D_115', 'D_117', 'D_118', 'D_119', 'D_120', 'D_121', 'D_122', 'D_123', 'D_124', 'D_125', 'D_126', 'D_128', 'D_129', 'D_131', 'D_132', 'D_133', 'D_134', 'D_135', 'D_136', 'D_140', 'D_141', 'D_142', 'D_144', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_2', 'R_3', 'R_7', 'R_8', 'R_9', 'R_10', 'R_11', 'R_14', 'R_15', 'R_16', 'R_17', 'R_20', 'R_21', 'R_22', 'R_24', 'R_26', 'R_27', 'S_3', 'S_5', 'S_6', 'S_7', 'S_9', 'S_11', 'S_12', 'S_13', 'S_15', 'S_16', 'S_18', 'S_22', 'S_23', 'S_25', 'S_26']
    feat = [F.col(c) for c in features_avg]
    exprs = {x: "avg" for x in features_avg}
    df_avg = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs)
          .rename({F.col(f"AVG({f})"): f"{f}_avg" for f in features_avg})
         )
    
    # Minimum
    features_min = ['B_2', 'B_4', 'B_5', 'B_9', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_19', 'B_20', 'B_28', 'B_29', 'B_33', 'B_36', 'B_42', 'D_39', 'D_41', 'D_42', 'D_45', 'D_46', 'D_48', 'D_50', 'D_51', 'D_53', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_62', 'D_70', 'D_71', 'D_74', 'D_75', 'D_78', 'D_83', 'D_102', 'D_112', 'D_113', 'D_115', 'D_118', 'D_119', 'D_121', 'D_122', 'D_128', 'D_132', 'D_140', 'D_141', 'D_144', 'D_145', 'P_2', 'P_3', 'R_1', 'R_27', 'S_3', 'S_5', 'S_7', 'S_9', 'S_11', 'S_12', 'S_23', 'S_25']
    exprs_min = {x: "min" for x in features_min}
    df_min = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs_min)
          .rename({F.col(f"MIN({f})"): f"{f}_min" for f in features_min})
         )
    
    # Maximum
    features_max = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_7', 'B_8', 'B_9', 'B_10', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_21', 'B_23', 'B_24', 'B_25', 'B_29', 'B_30', 'B_33', 'B_37', 'B_38', 'B_39', 'B_40', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_52', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_61', 'D_63', 'D_64', 'D_65', 'D_70', 'D_71', 'D_72', 'D_73', 'D_74', 'D_76', 'D_77', 'D_78', 'D_80', 'D_82', 'D_84', 'D_91', 'D_102', 'D_105', 'D_107', 'D_110', 'D_111', 'D_112', 'D_115', 'D_116', 'D_117', 'D_118', 'D_119', 'D_121', 'D_122', 'D_123', 'D_124', 'D_125', 'D_126', 'D_128', 'D_131', 'D_132', 'D_133', 'D_134', 'D_135', 'D_136', 'D_138', 'D_140', 'D_141', 'D_142', 'D_144', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_3', 'R_5', 'R_6', 'R_7', 'R_8', 'R_10', 'R_11', 'R_14', 'R_17', 'R_20', 'R_26', 'R_27', 'S_3', 'S_5', 'S_7', 'S_8', 'S_11', 'S_12', 'S_13', 'S_15', 'S_16', 'S_22', 'S_23', 'S_24', 'S_25', 'S_26', 'S_27']
    exprs_max = {x: "max" for x in features_max}
    df_max = (training_df
          .groupBy('"customer_ID"')
          .agg(exprs_max)
          .rename({F.col(f"MAX({f})"): f"{f}_max" for f in features_max})
         )
    
    # Last
    features_last = ['B_1', 'B_2', 'B_3', 'B_4', 'B_5', 'B_6', 'B_7', 'B_8', 'B_9', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_20', 'B_21', 'B_22', 'B_23', 'B_24', 'B_25', 'B_26', 'B_28', 'B_29', 'B_30', 'B_32', 'B_33', 'B_36', 'B_37', 'B_38', 'B_39', 'B_40', 'B_41', 'B_42', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_51', 'D_52', 'D_53', 'D_54', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_61', 'D_62', 'D_63', 'D_64', 'D_65', 'D_69', 'D_70', 'D_71', 'D_72', 'D_73', 'D_75', 'D_76', 'D_77', 'D_78', 'D_79', 'D_80', 'D_81', 'D_82', 'D_83', 'D_86', 'D_91', 'D_96', 'D_105', 'D_106', 'D_112', 'D_114', 'D_119', 'D_120', 'D_121', 'D_122', 'D_124', 'D_125', 'D_126', 'D_127', 'D_130', 'D_131', 'D_132', 'D_133', 'D_134', 'D_138', 'D_140', 'D_141', 'D_142', 'D_145', 'P_2', 'P_3', 'P_4', 'R_1', 'R_2', 'R_3', 'R_4', 'R_5', 'R_6', 'R_7', 'R_8', 'R_9', 'R_10', 'R_11', 'R_12', 'R_13', 'R_14', 'R_15', 'R_19', 'R_20', 'R_26', 'R_27', 'S_3', 'S_5', 'S_6', 'S_7', 'S_8', 'S_9', 'S_11', 'S_12', 'S_13', 'S_16', 'S_19', 'S_20', 'S_22', 'S_23', 'S_24', 'S_25', 'S_26', 'S_27', '"customer_ID"']
    w = snp.Window.partition_by('"customer_ID"').order_by(F.col('S_2').desc())
    df_last = training_df.withColumn("rn", F.row_number().over(w)).filter("rn = 1").select(features_last)
    
    # Join
    feature_df = df_min.natural_join(df_avg)
    feature_df = feature_df.natural_join(df_max)
    feature_df = feature_df.natural_join(df_last)
    
    feature_df.write.save_as_table(output_table, mode="append")
    
    return "Success"

# %%
session.sproc.register(feature_transform, name="feature_transform", replace=True, is_permanent=True, stage_location="@MODEL_ASSETS", packages=['snowflake-snowpark-python'], return_type = StringType())

# %%
session.call("feature_transform", "CC_DEFAULT_TRAINING_DATA", "TRANSFORMED_TABLE2")
